# %% [markdown]
# #### Overview

# %%
### Run a hyperparameter sweep on training script
### Compare the results of runs in MLFLOW UI
### Choose the best model and register it
### Deploy the model to restapi
### Build a container image suitable for deployment to cloud platform

# %% [markdown]
# #### Importing necessary libraries and dataset preparation

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK, fmin, hp, tpe, Trials
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mlflow/mlflow-example/master/wine-quality.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Splitting the data 
train,test = train_test_split(df,test_size=0.25,random_state=40)

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2213            7.4              0.17         0.29             1.4      0.047
# 3375            7.8              0.22         0.26             9.0      0.047
# 4596            6.7              0.53         0.29             4.3      0.069
# 4360            7.3              0.28         0.35             1.6      0.054
# 269             5.4              0.59         0.07             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 3603            7.0              0.32         0.27             7.1      0.027
# 4722            6.0              0.25         0.28             7.7      0.053
# 3340            6.2              0.30         0.31             1.2      0.048
# 3064            7.4              0.21         0.80            12.3      0.038
# 3398            6.1              0.33         0.32             7.8      0.052
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2213                 23.0                 107.0  0.99390  3.52       0.65
# 3375                 38.0                 132.0  0.99700  3.25       0.53
# 4596                 20.0                 114.0  0.99014  3.22       0.59
# 4360                 31.0                 148.0  0.99178  3.18       0.47
# 269                  36.0                 147.0  0.99440  3.34       0.57
# ...                   ...                   ...      ...   ...        ...
# 3603                 37.0                 122.0  0.99165  3.15       0.60
# 4722                 37.0                 132.0  0.99489  3.06       0.50
# 3340                 19.0                 125.0  0.98999  3.32       0.54
# 3064                 77.0                 183.0  0.99778  2.95       0.48
# 3398                 52.0                 183.0  0.99657  3.39       0.65
#
#       alcohol  quality
# 2213     10.4        6
# 3375     10.2        6
# 4596     13.4        6
# 4360     10.7        5
# 269       9.7        6
# ...       ...      ...
# 3603     12.6        7
# 4722      9.4        6
# 3340     12.6        6
# 3064      9.0        5
# 3398      9.5        5
#
# [3673 rows x 12 columns]

# %%
test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1876            8.0             0.190         0.30            2.00      0.053
# 147             6.4             0.595         0.14            5.20      0.058
# 3121            7.6             0.230         0.34            1.60      0.043
# 4778            5.8             0.315         0.19           19.40      0.031
# 4207            6.1             0.250         0.30            1.20      0.036
# ...             ...               ...          ...             ...        ...
# 2530            5.8             0.300         0.12            1.60      0.036
# 2335            8.3             0.270         0.34           10.20      0.048
# 3653            6.3             0.320         0.17           17.75      0.060
# 4232            6.6             0.390         0.28            9.20      0.036
# 1265            6.9             0.310         0.34            7.40      0.059
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1876                 48.0                 140.0  0.99400  3.18       0.49
# 147                  15.0                  97.0  0.99510  3.38       0.36
# 3121                 24.0                 129.0  0.99305  3.12       0.70
# 4778                 28.0                 106.0  0.99704  2.97       0.40
# 4207                 42.0                 107.0  0.99100  3.34       0.56
# ...                   ...                   ...      ...   ...        ...
# 2530                 57.0                 163.0  0.99239  3.38       0.59
# 2335                 50.0                 118.0  0.99716  3.18       0.51
# 3653                 51.0                 190.0  0.99916  3.13       0.48
# 4232                 10.0                  92.0  0.99206  3.07       0.35
# 1265                 36.0                 174.0  0.99630  3.46       0.62
#
#       alcohol  quality
# 1876     9.60        6
# 147      9.00        4
# 3121    10.40        5
# 4778    10.55        6
# 4207    10.80        7
# ...       ...      ...
# 2530    10.50        6
# 2335    10.30        5
# 3653     8.80        6
# 4232    12.10        6
# 1265    11.10        7
#
# [1225 rows x 12 columns]

# %%
X_train = train.drop(['quality'],axis=1).values
y_train = train[['quality']].values.ravel()  
## ravel() gives us o/p y_train array as 1D instead of 2D

# Test Dataset
X_test = test.drop(['quality'],axis=1).values
y_test = test[['quality']].values.ravel()

# %%
## Splitting this data into train and validation
X_train,X_valid,y_train,y_valid=train_test_split(X_train,y_train,test_size=0.2,random_state=40)

# %%
signature = infer_signature(X_train,y_train)

# %% [markdown]
# #### Training model

# %%
import keras.layers
import keras.metrics
import keras.optimizers


def train_model(params,epochs,X_train,y_train,X_test,y_test,X_valid,y_valid,):

    mean = np.mean(X_train,axis=0)  ## column wise mean
    var = np.var(X_train,axis=0)

    ## model architecture
    model = keras.Sequential(
        [
            keras.Input([X_train.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation="relu"),
            keras.layers.Dense(1)
        ]
    )

    ## compile model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],
        momentum=params["momentum"]),
        loss= "mean_squared_error",
        metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Training ANN model with lr and momentum params and tracking using MLFLOW
    with mlflow.start_run(nested=True):
        model.fit(X_train,y_train,validation_data=(X_valid,y_valid),
                  epochs=epochs,
                  batch_size=64
                  )
        
        #evaluating the model
        eval_result=model.evaluate(X_valid,y_valid,batch_size=64)
        eval_rmse=eval_result[1]

        ## Logging the paramaeters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## Logging the model
        mlflow.tensorflow.log_model(model,"model_1",signature=signature)

        return {"loss":eval_rmse,
                "status": STATUS_OK,
                "model": model
                }

# %%
def objective(params):
    ## MLFlow will track all the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        y_test=y_test,
        X_valid=X_valid,
        y_valid=y_valid,
    )
    return result

# %%
space = {
    "lr" : hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum" : hp.uniform("momentum",0,1)
}

# %%
mlflow.set_experiment("/02_DL_MLFLOW")
with mlflow.start_run():
    ## conducting hyperparameter tuning search using hyperopt's trial
    trials=Trials()
    best=fmin(
        fn = objective,
        space = space,
        algo = tpe.suggest,
        max_evals = 3,
        trials = trials
    )

    #Fetching best details of best run
    best_run = sorted(trials.results,key=lambda x: x["loss"])[0]

    ## Log best parameters , loss and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse",best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"],"model",signature=signature)

    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/46 [..............................] - ETA: 6s - loss: 38.2860 - root_mean_squared_error: 6.1876
#   0%|          | 0/3 [00:00<?, ?trial/s, best loss=?]
# 2024-11-04 16:37:28.602015: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 46/46 [==============================] - 0s 2ms/step - loss: 7.5456 - root_mean_squared_error: 2.7469 - val_loss: 1.6954 - val_root_mean_squared_error: 1.3021
#
# Epoch 2/3
#
#  1/46 [..............................] - ETA: 0s - loss: 2.1218 - root_mean_squared_error: 1.4567
# 46/46 [==============================] - 0s 687us/step - loss: 1.0969 - root_mean_squared_error: 1.0473 - val_loss: 0.7473 - val_root_mean_squared_error: 0.8645
#
# Epoch 3/3
#
#  1/46 [..............................] - ETA: 0s - loss: 1.3569 - root_mean_squared_error: 1.1648
# 46/46 [==============================] - 0s 662us/step - loss: 0.6846 - root_mean_squared_error: 0.8274 - val_loss: 0.6440 - val_root_mean_squared_error: 0.8025
#
#  1/12 [=>............................] - ETA: 0s - loss: 0.7141 - root_mean_squared_error: 0.8450
# 12/12 [==============================] - 0s 501us/step - loss: 0.6440 - root_mean_squared_error: 0.8025
#
#   0%|          | 0/3 [00:00<?, ?trial/s, best loss=?]INFO:tensorflow:Assets written to: /var/folders/yp/x_6z7w4s4pn9l27krxyysdnh0000gn/T/tmpy4aat5iv/model/data/model/assets
# Epoch 1/3
#
#  1/46 [..............................] - ETA: 4s - loss: 38.5433 - root_mean_squared_error: 6.2083
# 46/46 [==============================] - 0s 2ms/step - loss: 33.9475 - root_mean_squared_error: 5.8264 - val_loss: 28.8721 - val_root_mean_squared_error: 5.3733
#
# Epoch 2/3
#
#  1/46 [..............................] - ETA: 0s - loss: 30.4343 - root_mean_squared_error: 5.5167
# 46/46 [==============================] - 0s 702us/step - loss: 26.1350 - root_mean_squared_error: 5.1122 - val_loss: 22.1399 - val_root_mean_squared_error: 4.7053
#
# Epoch 3/3
#
#  1/46 [..............................] - ETA: 0s - loss: 20.7458 - root_mean_squared_error: 4.5548
# 46/46 [==============================] - 0s 655us/step - loss: 20.1743 - root_mean_squared_error: 4.4916 - val_loss: 16.9495 - val_root_mean_squared_error: 4.1170
#
#  1/12 [=>............................] - ETA: 0s - loss: 15.4315 - root_mean_squared_error: 3.9283
# 12/12 [==============================] - 0s 484us/step - loss: 16.9495 - root_mean_squared_error: 4.1170
#
#  33%|███▎      | 1/3 [00:05<00:09,  4.89s/trial, best loss: 0.8024770617485046]INFO:tensorflow:Assets written to: /var/folders/yp/x_6z7w4s4pn9l27krxyysdnh0000gn/T/tmpmo7fndyb/model/data/model/assets
# Epoch 1/3
#
#  1/46 [..............................] - ETA: 4s - loss: 34.4167 - root_mean_squared_error: 5.8666
# 46/46 [==============================] - 0s 2ms/step - loss: 29.7299 - root_mean_squared_error: 5.4525 - val_loss: 26.3205 - val_root_mean_squared_error: 5.1304
#
# Epoch 2/3
#
#  1/46 [..............................] - ETA: 0s - loss: 28.2661 - root_mean_squared_error: 5.3166
# 46/46 [==============================] - 0s 700us/step - loss: 24.4017 - root_mean_squared_error: 4.9398 - val_loss: 21.3093 - val_root_mean_squared_error: 4.6162
#
# Epoch 3/3
#
#  1/46 [..............................] - ETA: 0s - loss: 21.3059 - root_mean_squared_error: 4.6158
# 46/46 [==============================] - 0s 645us/step - loss: 19.8022 - root_mean_squared_error: 4.4500 - val_loss: 17.2582 - val_root_mean_squared_error: 4.1543
#
#  1/12 [=>............................] - ETA: 0s - loss: 18.1234 - root_mean_squared_error: 4.2572
# 12/12 [==============================] - 0s 493us/step - loss: 17.2582 - root_mean_squared_error: 4.1543
#
#  67%|██████▋   | 2/3 [00:07<00:03,  3.51s/trial, best loss: 0.8024770617485046]INFO:tensorflow:Assets written to: /var/folders/yp/x_6z7w4s4pn9l27krxyysdnh0000gn/T/tmpj43sitm3/model/data/model/assets
# 100%|██████████| 3/3 [00:09<00:00,  3.33s/trial, best loss: 0.8024770617485046]
# INFO:tensorflow:Assets written to: /var/folders/yp/x_6z7w4s4pn9l27krxyysdnh0000gn/T/tmptkxmh3qm/model/data/model/assets
# Best parameters: {'lr': 0.0029864501009612752, 'momentum': 0.9367403203821787}
# Best eval rmse: 0.8024770617485046
